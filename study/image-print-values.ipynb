# %%
from PIL import Image
import numpy as np

# Carregar a imagem
image_path = "random/elephant.jpeg"
image = Image.open(image_path)

# Converter a imagem para escala de cinza (se necessário) e redimensionar para 28x28 (para corresponder ao formato MNIST)
image = image.convert('L').resize((28, 28))

# Converter a imagem para uma matriz numpy
image_array = np.array(image)

# Imprimir cada linha da imagem em uma linha separada
for row in image_array:
    print(' '.join([f'{pixel:3}' for pixel in row]))
# Out:
# 196 201 203 202 203 205 208 207 217 214 212 221 218 209 209 206 205 205 205 204 204 206 206 204 202 198 193 192
# 203 212 209 207 203 204 207 212 216 214 217 221 217 209 206 206 206 207 206 205 206 212 210 201 199 197 196 195
# 204 210 216 213 209 211 211 212 215 212 214 215 216 215 210 209 208 209 207 206 206 205 205 204 202 201 199 198
# 210 211 215 216 217 221 220 220 219 214 217 217 216 214 213 211 210 210 210 208 208 207 205 205 204 203 202 200
# 215 217 218 220 198 170 222 219 219 218 220 222 223 222 220 218 217 215 211 211 210 209 208 206 205 205 204 203
# 215 217 218 219 214 129 201 222 221 220 219 218 203 217 221 220 220 220 215 214 214 212 210 208 207 206 206 205
# 213 215 216 217 227 127 162 227 212 188 184 159 156 193 216 215 213 210 202 202 212 216 213 212 211 210 209 208
# 209 210 213 217 221  91 171 223 179 165 125  93 138 159 191 209 206 208 207 200 201 208 213 211 210 209 209 207
# ...

# %%
image2 = image.convert('RGB').resize((28, 28))
image_array = np.array(image2)

# Imprimir os valores dos três canais para cada pixel
for row in image_array:
    for pixel in row:
        print(f'({pixel[0]:3}, {pixel[1]:3}, {pixel[2]:3})', end=' ')
    print()
# Out:
# (196, 196, 196) (201, 201, 201) (203, 203, 203) (202, 202, 202) (203, 203, 203) (205, 205, 205) (208, 208, 208) (207, 207, 207) (216, 216, 216) (213, 213, 213) (212, 212, 212) (221, 221, 221) (218, 218, 218) (209, 209, 209) (209, 209, 209) (206, 206, 206) (205, 205, 205) (205, 205, 205) (205, 205, 205) (204, 204, 204) (204, 204, 204) (206, 206, 206) (206, 206, 206) (205, 205, 205) (202, 202, 202) (198, 198, 198) (193, 193, 193) (192, 192, 192)
# (202, 202, 202) (212, 212, 212) (210, 210, 210) (207, 207, 207) (203, 203, 203) (203, 203, 203) (207, 207, 207) (212, 212, 212) (216, 216, 216) (215, 215, 215) (217, 217, 217) (221, 221, 221) (217, 217, 217) (209, 209, 209) (206, 206, 206) (206, 206, 206) (206, 206, 206) (208, 208, 208) (206, 206, 206) (205, 205, 205) (206, 206, 206) (212, 212, 212) (209, 209, 209) (201, 201, 201) (198, 198, 198) (197, 197, 197) (196, 196, 196) (195, 195, 195)
# ...
