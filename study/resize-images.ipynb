# %%
import os
import xml.etree.ElementTree as ET
from PIL import Image

# %%
def resize_image(image_path, scale_factor):
    with Image.open(image_path) as img:
        new_size = (int(img.width * scale_factor), int(img.height * scale_factor))
        resized_img = img.resize(new_size, Image.Resampling.LANCZOS)  # Usando LANCZOS para alta qualidade de redimensionamento
        return resized_img

def resize_bounding_boxes(xml_file_path, scale_factor):
    # Parse do XML
    tree = ET.parse(xml_file_path)
    root = tree.getroot()

    # Atualiza a largura e altura na tag <size>
    size = root.find('size')
    size.find('width').text = str(int(int(size.find('width').text) * scale_factor))
    size.find('height').text = str(int(int(size.find('height').text) * scale_factor))

    # Atualiza as coordenadas das bounding boxes
    for obj in root.findall('object'):
        bndbox = obj.find('bndbox')
        xmin = bndbox.find('xmin')
        ymin = bndbox.find('ymin')
        xmax = bndbox.find('xmax')
        ymax = bndbox.find('ymax')
        
        xmin.text = str(float(xmin.text) * scale_factor)
        ymin.text = str(float(ymin.text) * scale_factor)
        xmax.text = str(float(xmax.text) * scale_factor)
        ymax.text = str(float(ymax.text) * scale_factor)

    return tree

def process_directory(annotation_path, image_path, image_dest_path, xml_dest_path, scale_factor):
    # Cria os diretórios de destino se não existirem
    os.makedirs(image_dest_path, exist_ok=True)
    os.makedirs(xml_dest_path, exist_ok=True)

    # Lista todos os arquivos no diretório
    for filename in os.listdir(annotation_path):
        if filename.endswith('.xml'):
            xml_file_path = os.path.join(annotation_path, filename)
            
            # Obtém o nome do arquivo de imagem a partir do XML
            tree = ET.parse(xml_file_path)
            root = tree.getroot()
            image_filename = root.find('filename').text
            image_path_tmp = os.path.join(image_path, image_filename)
            
            # Redimensiona a imagem
            resized_image = resize_image(image_path_tmp, scale_factor)
            new_image_filename = f"{image_filename}"
            new_image_path = os.path.join(image_dest_path, new_image_filename)
            resized_image.save(new_image_path)
            print(f"Imagem redimensionada salva em: {new_image_path}")
            
            # Redimensiona as bounding boxes
            tree = resize_bounding_boxes(xml_file_path, scale_factor)
            
            # Caminho para salvar o novo arquivo XML redimensionado
            new_xml_file_path = os.path.join(xml_dest_path, f"{filename}")
            tree.write(new_xml_file_path)
            print(f"Arquivo XML redimensionado salvo em: {new_xml_file_path}")

# %%
# Diretório contendo os arquivos XML
annotation_path = 'D:/python/tcc1/annotations-orig/'

# Diretório contendo os arquivos imagens
image_path = 'D:/python/tcc1/images-orig'

# Diretório de destino para arquivos XML redimensionados
xml_dest_path = 'D:/python/tcc1/annotations/'

# Diretório de destino para imagens redimensionadas
image_dest_path = 'D:/python/tcc1/images/'

# Fator de redimensionamento (0.5 para 50%)
scale_factor = 0.2

# %%
# Processa o diretório
process_directory(annotation_path, image_path, image_dest_path, xml_dest_path, scale_factor)
# Out:
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_0.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_0.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_1.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_1.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_10.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_10.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_102.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_102.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_103.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_103.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_11.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_11.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_111.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_111.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_116.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_116.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_117.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_117.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_118.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_118.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_119.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_119.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_12.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_12.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_120.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_120.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_122.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_122.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_123.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_123.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_124.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_124.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_126.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_126.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_127.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_127.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_128.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_128.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_129.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_129.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_13.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_13.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_130.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_130.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_131.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_131.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_132.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_132.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_133.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_133.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_134.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_134.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_135.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_135.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_137.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_137.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_138.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_138.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_139.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_139.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_14.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_14.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_140.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_140.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_141.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_141.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_142.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_142.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_144.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_144.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_145.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_145.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_147.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_147.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_15.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_15.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_151.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_151.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_152.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_152.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_154.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_154.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_16.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_16.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_17.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_17.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_18.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_18.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_19.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_19.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_2.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_2.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_20.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_20.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_21.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_21.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_22.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_22.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_23.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_23.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_24.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_24.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_25.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_25.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_26.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_26.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_27.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_27.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_28.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_28.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_29.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_29.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_3.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_3.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_30.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_30.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_31.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_31.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_32.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_32.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_34.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_34.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_35.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_35.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_36.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_36.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_37.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_37.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_38.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_38.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_39.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_39.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_4.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_4.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_40.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_40.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_41.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_41.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_42.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_42.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_43.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_43.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_44.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_44.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_46.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_46.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_47.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_47.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_49.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_49.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_5.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_5.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_52.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_52.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_55.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_55.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_56.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_56.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_58.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_58.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_59.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_59.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_6.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_6.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_62.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_62.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_63.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_63.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_64.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_64.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_69.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_69.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_7.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_7.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_71.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_71.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_72.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_72.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_73.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_73.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_74.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_74.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_75.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_75.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_76.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_76.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_77.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_77.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_8.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_8.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_83.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_83.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_84.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_84.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_88.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_88.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_89.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_89.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_9.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_9.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_90.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_90.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_91.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_91.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_92.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_92.xml
# Imagem redimensionada salva em: D:/python/tcc1/images/GX010061.MP4_93.png
# Arquivo XML redimensionado salvo em: D:/python/tcc1/annotations/GX010061.MP4_93.xml
