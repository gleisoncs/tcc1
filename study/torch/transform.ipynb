# %%
# Image Classification
import torch
from torchvision.transforms import v2

# %%
H, W = 32, 32
img = torch.randint(0, 256, size=(3, H, W), dtype=torch.uint8)

print(img)
# Out:
# tensor([[[ 28, 129,  38,  ...,   8, 254, 106],
#          [177, 235,  60,  ...,  91,  45, 215],
#          [ 71,  69, 227,  ..., 180, 196, 134],
#          ...,
#          [111, 109, 134,  ...,  30,  87, 206],
#          [200,  32,  38,  ...,  68, 225, 196],
#          [140,  31, 234,  ..., 107,  98, 182]],
#
#         [[171, 253, 102,  ...,  39,  96,  23],
#          [ 80, 106, 227,  ..., 113,  66, 101],
#          [239, 160, 101,  ..., 103,  84,   6],
#          ...,
#          [ 25,   6, 139,  ..., 197,  29, 105],
#          [ 44, 154, 152,  ...,   1, 240,  19],
#          [150, 195,  78,  ..., 218,  51, 171]],
#
#         [[214,  18, 139,  ..., 248, 109, 138],
#          [ 14, 219, 191,  ..., 128, 125,  42],
#          [155, 148,  53,  ...,  97, 121, 115],
#          ...,
#          [132, 196,  87,  ..., 112,  58,   0],
#          [ 61, 185,  46,  ...,  96,  29,  16],
#          [189,  13, 156,  ...,  70, 142, 148]]], dtype=torch.uint8)

# %%
transforms = v2.Compose([
    v2.RandomResizedCrop(size=(224, 224), antialias=True),
    v2.RandomHorizontalFlip(p=0.5),
    v2.RandomPerspective(distortion_scale=0.6, p=1.0),
    v2.ToDtype(torch.float32, scale=True),
    v2.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

img = transforms(img)

print(img)
# Out:
# tensor([[[-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#          [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#          [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#          ...,
#          [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#          [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#          [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179]],
#
#         [[-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#          [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#          [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#          ...,
#          [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#          [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#          [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357]],
#
#         [[-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#          [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#          [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#          ...,
#          [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#          [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#          [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044]]])
